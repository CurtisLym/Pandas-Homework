# %% [markdown]
# ## Whale Portfolio

# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path

# %% [markdown]
# # Portfolio paths

# %%
whale_file = Path('whale_returns.csv')
algo_file = Path('algo_returns.csv')
sptsx_file = Path('sp_tsx_history.csv')

# %%
#read_csv
whaledf = pd.read_csv(whale_file, index_col='Date', infer_datetime_format=True, parse_dates=True)
algodf = pd.read_csv(algo_file, index_col='Date', infer_datetime_format=True, parse_dates=True)
aptsxdf = pd.read_csv(sptsx_file, index_col='Date', infer_datetime_format=True, parse_dates=True)
#infer dates

# %% [markdown]
# ## Whale Returns

# %%
# Reading whale returns
#change the date to datetime frames
whaledf.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whaledf.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whaledf = whaledf.dropna()
whaledf
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1059 rows x 4 columns]

# %%
whaledf.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns

# %%
# Reading algorithmic returns
algodf.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algodf.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algodf = algodf.dropna()
algodf
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %%
algodf.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P TSX 60 Returns

# %%
# Reading S&P TSX 60 Closing Prices
aptsxdf.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
aptsxdf.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
#Removing '$'
aptsxdf['Close'] = aptsxdf['Close'].str.replace('$', '')
aptsxdf['Close'] = aptsxdf['Close'].str.replace(',', '')
aptsxdf['Close'] = aptsxdf['Close'].str.replace(' ', '')
aptsxdf['Close'] = aptsxdf['Close'].astype('float')
#Turns the column 'Close' values from a object to float
aptsxdf.dtypes
# Out:
# C:\Users\Curtis lym\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
#Setting the 'Date' as the index to the DataFrame

# %%
# Calculate Daily Returns
aptsxdf_dreturns = aptsxdf.pct_change().dropna()
aptsxdf_dreturns
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1817 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
aptsxdf_dreturns.columns = ['SP&60']
aptsxdf_dreturns.head()
# Out:
#                SP&60
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
joined_data = pd.concat([whaledf, algodf, aptsxdf_dreturns], axis='columns', join='inner')
joined_data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# ...                                 ...                     ...       ...
# 2019-04-25                    -0.005153                0.004848  0.000682
# 2019-04-26                     0.012355                0.010434  0.002981
# 2019-04-29                     0.006251                0.005223  0.005208
# 2019-04-30                    -0.000259               -0.003702 -0.002944
# 2019-05-01                    -0.007936               -0.007833  0.000094
#
#               Algo 2     SP&60
# Date
# 2015-03-03 -0.000949 -0.008530
# 2015-03-04  0.002416 -0.003371
# 2015-03-05  0.004323  0.001344
# 2015-03-06 -0.011460 -0.009972
# 2015-03-09  0.001303 -0.006555
# ...              ...       ...
# 2019-04-25 -0.007247 -0.000628
# 2019-04-26  0.005256  0.002254
# 2019-04-29  0.002829 -0.000788
# 2019-04-30 -0.001570 -0.001183
# 2019-05-01 -0.007358 -0.004703
#
# [1029 rows x 7 columns]

# %% [markdown]
# ## Conduct Quantitative Analysis

# %% [markdown]
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ### Calculate and Plot the daily returns.

# %%
#Calculate and Plot the daily returns.
joined_data.plot(figsize=(20, 10), title='Daily Returns')
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and Plot cumulative returns

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + joined_data).cumprod()
cumulative_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
# ...                               ...                 ...
# 2019-04-25                   1.118163            0.754821
# 2019-04-26                   1.127275            0.761736
# 2019-04-29                   1.128689            0.763808
# 2019-04-30                   1.127228            0.762119
# 2019-05-01                   1.120637            0.761096
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
# ...                                 ...                     ...       ...
# 2019-04-25                     0.840272                1.348932  2.011144
# 2019-04-26                     0.850654                1.363007  2.017139
# 2019-04-29                     0.855971                1.370126  2.027645
# 2019-04-30                     0.855749                1.365054  2.021675
# 2019-05-01                     0.848958                1.354361  2.021865
#
#               Algo 2     SP&60
# Date
# 2015-03-03  0.999051  0.991470
# 2015-03-04  1.001464  0.988128
# 2015-03-05  1.005794  0.989456
# 2015-03-06  0.994267  0.979589
# 2015-03-09  0.995563  0.973168
# ...              ...       ...
# 2019-04-25  1.196390  1.070504
# 2019-04-26  1.202677  1.072916
# 2019-04-29  1.206080  1.072071
# 2019-04-30  1.204187  1.070803
# 2019-05-01  1.195327  1.065767
#
# [1029 rows x 7 columns]

# %%
# Plot cumulative returns
cumulative_returns.plot(figsize=(20, 10), title='Cumulative Returns')
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# # Risk Analysis
# ## Determine the risk of each portfolio:

# %%
#Create a box plot for each portfolio
# Box plot to visually show risk
#below is the correct format
joined_data.plot.box(figsize=(20, 10), title='Risk Analysis')
# Out:
# <AxesSubplot:title={'center':'Risk Analysis'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
all_portfolio_std = joined_data.std()
all_portfolio_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# SP&60                          0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
sp_500_std = round(all_portfolio_std['SP&60'], 6)
sp_500_std
# Out:
# 0.007034

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Determine which portfolios are riskier than the S&P TSX 60
all_portfolio_std > sp_500_std
# Out:
# SOROS FUND MANAGEMENT LLC       True
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                          True
# Algo 2                          True
# SP&60                           True
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = all_portfolio_std * np.sqrt(252)
annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# dtype: float64

# %% [markdown]
# # Rolling Statistics

# %% [markdown]
# ## Calculate and plot rolling std for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
portfolios_21day_rolling = joined_data.rolling(window=21).std()
# Plot the rolling standard deviation
portfolios_21day_rolling.plot(figsize=(40, 20))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Calculate and plot the correlation

# %% [markdown]
# ## Question

# %%
# Calculate the correlation
correlation_portfolios = joined_data.corr()
# Display de correlation matrix
correlation_portfolios.style.background_gradient(cmap="summer")
# Out:
# <style  type="text/css" >
# #T_d3f1e_row0_col0,#T_d3f1e_row1_col1,#T_d3f1e_row2_col2,#T_d3f1e_row3_col3,#T_d3f1e_row4_col4,#T_d3f1e_row5_col5,#T_d3f1e_row6_col6{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_d3f1e_row0_col1{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_d3f1e_row0_col2{
#             background-color:  #7abc66;
#             color:  #000000;
#         }#T_d3f1e_row0_col3{
#             background-color:  #a6d266;
#             color:  #000000;
#         }#T_d3f1e_row0_col4{
#             background-color:  #2e9666;
#             color:  #000000;
#         }#T_d3f1e_row0_col5{
#             background-color:  #c1e066;
#             color:  #000000;
#         }#T_d3f1e_row0_col6,#T_d3f1e_row6_col0{
#             background-color:  #86c266;
#             color:  #000000;
#         }#T_d3f1e_row1_col0,#T_d3f1e_row5_col1,#T_d3f1e_row5_col3{
#             background-color:  #8ec666;
#             color:  #000000;
#         }#T_d3f1e_row1_col2{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_d3f1e_row1_col3{
#             background-color:  #5aac66;
#             color:  #000000;
#         }#T_d3f1e_row1_col4{
#             background-color:  #209066;
#             color:  #000000;
#         }#T_d3f1e_row1_col5{
#             background-color:  #8bc566;
#             color:  #000000;
#         }#T_d3f1e_row1_col6{
#             background-color:  #41a066;
#             color:  #000000;
#         }#T_d3f1e_row2_col0{
#             background-color:  #5cae66;
#             color:  #000000;
#         }#T_d3f1e_row2_col1{
#             background-color:  #3a9c66;
#             color:  #000000;
#         }#T_d3f1e_row2_col3,#T_d3f1e_row2_col6{
#             background-color:  #309866;
#             color:  #000000;
#         }#T_d3f1e_row2_col4,#T_d3f1e_row4_col0,#T_d3f1e_row4_col1,#T_d3f1e_row4_col2,#T_d3f1e_row4_col3,#T_d3f1e_row4_col5,#T_d3f1e_row4_col6{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_d3f1e_row2_col5{
#             background-color:  #4fa766;
#             color:  #000000;
#         }#T_d3f1e_row3_col0{
#             background-color:  #a2d066;
#             color:  #000000;
#         }#T_d3f1e_row3_col1{
#             background-color:  #5faf66;
#             color:  #000000;
#         }#T_d3f1e_row3_col2{
#             background-color:  #50a866;
#             color:  #000000;
#         }#T_d3f1e_row3_col4{
#             background-color:  #279366;
#             color:  #000000;
#         }#T_d3f1e_row3_col5{
#             background-color:  #8fc766;
#             color:  #000000;
#         }#T_d3f1e_row3_col6{
#             background-color:  #5bad66;
#             color:  #000000;
#         }#T_d3f1e_row5_col0{
#             background-color:  #bfdf66;
#             color:  #000000;
#         }#T_d3f1e_row5_col2{
#             background-color:  #69b466;
#             color:  #000000;
#         }#T_d3f1e_row5_col4{
#             background-color:  #259266;
#             color:  #000000;
#         }#T_d3f1e_row5_col6{
#             background-color:  #9ece66;
#             color:  #000000;
#         }#T_d3f1e_row6_col1{
#             background-color:  #4ca666;
#             color:  #000000;
#         }#T_d3f1e_row6_col2{
#             background-color:  #55aa66;
#             color:  #000000;
#         }#T_d3f1e_row6_col3{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_d3f1e_row6_col4{
#             background-color:  #2d9666;
#             color:  #000000;
#         }#T_d3f1e_row6_col5{
#             background-color:  #a1d066;
#             color:  #000000;
#         }</style><table id="T_d3f1e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>        <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>        <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>        <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>        <th class="col_heading level0 col4" >Algo 1</th>        <th class="col_heading level0 col5" >Algo 2</th>        <th class="col_heading level0 col6" >SP&60</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d3f1e_level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#                         <td id="T_d3f1e_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_d3f1e_row0_col1" class="data row0 col1" >0.697076</td>
#                         <td id="T_d3f1e_row0_col2" class="data row0 col2" >0.560964</td>
#                         <td id="T_d3f1e_row0_col3" class="data row0 col3" >0.750181</td>
#                         <td id="T_d3f1e_row0_col4" class="data row0 col4" >0.313795</td>
#                         <td id="T_d3f1e_row0_col5" class="data row0 col5" >0.826667</td>
#                         <td id="T_d3f1e_row0_col6" class="data row0 col6" >0.673930</td>
#             </tr>
#             <tr>
#                         <th id="T_d3f1e_level0_row1" class="row_heading level0 row1" >PAULSON & CO.INC. </th>
#                         <td id="T_d3f1e_row1_col0" class="data row1 col0" >0.697076</td>
#                         <td id="T_d3f1e_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_d3f1e_row1_col2" class="data row1 col2" >0.433034</td>
#                         <td id="T_d3f1e_row1_col3" class="data row1 col3" >0.540033</td>
#                         <td id="T_d3f1e_row1_col4" class="data row1 col4" >0.266363</td>
#                         <td id="T_d3f1e_row1_col5" class="data row1 col5" >0.674015</td>
#                         <td id="T_d3f1e_row1_col6" class="data row1 col6" >0.486511</td>
#             </tr>
#             <tr>
#                         <th id="T_d3f1e_level0_row2" class="row_heading level0 row2" >TIGER GLOBAL MANAGEMENT LLC</th>
#                         <td id="T_d3f1e_row2_col0" class="data row2 col0" >0.560964</td>
#                         <td id="T_d3f1e_row2_col1" class="data row2 col1" >0.433034</td>
#                         <td id="T_d3f1e_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_d3f1e_row2_col3" class="data row2 col3" >0.423524</td>
#                         <td id="T_d3f1e_row2_col4" class="data row2 col4" >0.161236</td>
#                         <td id="T_d3f1e_row2_col5" class="data row2 col5" >0.506689</td>
#                         <td id="T_d3f1e_row2_col6" class="data row2 col6" >0.440583</td>
#             </tr>
#             <tr>
#                         <th id="T_d3f1e_level0_row3" class="row_heading level0 row3" >BERKSHIRE HATHAWAY INC</th>
#                         <td id="T_d3f1e_row3_col0" class="data row3 col0" >0.750181</td>
#                         <td id="T_d3f1e_row3_col1" class="data row3 col1" >0.540033</td>
#                         <td id="T_d3f1e_row3_col2" class="data row3 col2" >0.423524</td>
#                         <td id="T_d3f1e_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_d3f1e_row3_col4" class="data row3 col4" >0.289378</td>
#                         <td id="T_d3f1e_row3_col5" class="data row3 col5" >0.684609</td>
#                         <td id="T_d3f1e_row3_col6" class="data row3 col6" >0.557250</td>
#             </tr>
#             <tr>
#                         <th id="T_d3f1e_level0_row4" class="row_heading level0 row4" >Algo 1</th>
#                         <td id="T_d3f1e_row4_col0" class="data row4 col0" >0.313795</td>
#                         <td id="T_d3f1e_row4_col1" class="data row4 col1" >0.266363</td>
#                         <td id="T_d3f1e_row4_col2" class="data row4 col2" >0.161236</td>
#                         <td id="T_d3f1e_row4_col3" class="data row4 col3" >0.289378</td>
#                         <td id="T_d3f1e_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_d3f1e_row4_col5" class="data row4 col5" >0.285455</td>
#                         <td id="T_d3f1e_row4_col6" class="data row4 col6" >0.310276</td>
#             </tr>
#             <tr>

# %% [markdown]
# ## Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %% [markdown]
# # Question

# %%
# Calculate covariance of a single portfolio
covariance = joined_data["Algo 1"].rolling(window=60).cov(joined_data["SP&60"])
# Calculate variance of S&P TSX
sp_variance = joined_data["SP&60"].rolling(window=60).var()
# Computing beta
portfolio_beta = covariance / sp_variance
# Plot beta trend
portfolio_beta.plot(figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Rolling Statistics Challenge: Exponentially Weighted Average
# ## Use `ewm` to calculate the rolling window

# %% [markdown]
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
joined_data.ewm(halflife=21).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Sharpe Ratios
# Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %% [markdown]
# # Question

# %%
# Annualized Sharpe Ratios
sharpe_ratios = ((joined_data.mean()-joined_data['SP&60'].mean()) * 252) / (joined_data.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.110980
# PAULSON & CO.INC.             -0.744596
# TIGER GLOBAL MANAGEMENT LLC   -0.270851
# BERKSHIRE HATHAWAY INC         0.359795
# Algo 1                         1.310258
# Algo 2                         0.231615
# SP&60                          0.000000
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar', figsize=(20, 10), title='Sharp Ratio')
# Out:
# <AxesSubplot:title={'center':'Sharp Ratio'}>

# %%
#Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#Write your answer here!

# %% [markdown]
# # Create Custom Portfolio

# %% [markdown]
# Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
tsla_file = Path('TSLA.csv')
tsla_df = pd.read_csv(tsla_file, index_col='Date', infer_datetime_format=True, parse_dates=True)
tsla_df.columns = ['TSLA']
tsla_df.head()
# Out:
#                       TSLA
# Date
# 2018-01-02 16:00:00  64.11
# 2018-01-03 16:00:00  63.45
# 2018-01-04 16:00:00  62.92
# 2018-01-05 16:00:00  63.32
# 2018-01-08 16:00:00  67.28

# %%
# Reading data from 2nd stock
apple_file = Path('APPLE.csv')
apple_df = pd.read_csv(tsla_file, index_col='Date', infer_datetime_format=True, parse_dates=True)
apple_df.columns = ['APPLE']
apple_df.head()
# Out:
#                      APPLE
# Date
# 2018-01-02 16:00:00  64.11
# 2018-01-03 16:00:00  63.45
# 2018-01-04 16:00:00  62.92
# 2018-01-05 16:00:00  63.32
# 2018-01-08 16:00:00  67.28

# %%
# Reading data from 3rd stock
bestbuy_file = Path('BESTBUY.csv')
bestbuy_df = pd.read_csv(bestbuy_file, index_col='Date', infer_datetime_format=True, parse_dates=True)
bestbuy_df.columns = ['BEST_BUY']
bestbuy_df.head()
# Out:
#                      BEST_BUY
# Date
# 2018-01-02 16:00:00     69.16
# 2018-01-03 16:00:00     68.40
# 2018-01-04 16:00:00     67.28
# 2018-01-05 16:00:00     68.87
# 2018-01-08 16:00:00     69.69

# %%
# Combine all stocks in a single DataFrame
all_3_portfolios = pd.concat([tsla_df, apple_df, bestbuy_df], axis='columns', join='inner')

# %% [markdown]
# ## Question

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol
all_3_portfolios.head()
# Out:
#                       TSLA  APPLE  BEST_BUY
# Date
# 2018-01-02 16:00:00  64.11  64.11     69.16
# 2018-01-03 16:00:00  63.45  63.45     68.40
# 2018-01-04 16:00:00  62.92  62.92     67.28
# 2018-01-05 16:00:00  63.32  63.32     68.87
# 2018-01-08 16:00:00  67.28  67.28     69.69

# %%
# Calculate daily returns
# Drop NAs
all_3_portfolio_returns = all_3_portfolios.pct_change().dropna()
# Display sample data
all_3_portfolio_returns
# Out:
#                          TSLA     APPLE  BEST_BUY
# Date
# 2018-01-03 16:00:00 -0.010295 -0.010295 -0.010989
# 2018-01-04 16:00:00 -0.008353 -0.008353 -0.016374
# 2018-01-05 16:00:00  0.006357  0.006357  0.023633
# 2018-01-08 16:00:00  0.062539  0.062539  0.011906
# 2018-01-09 16:00:00 -0.008026 -0.008026  0.001291
# ...                       ...       ...       ...
# 2019-12-20 16:00:00  0.003836  0.003836 -0.010266
# 2019-12-23 16:00:00  0.033531  0.033531 -0.001026
# 2019-12-24 13:00:00  0.014432  0.014432  0.003309
# 2019-12-26 16:00:00  0.013404  0.013404 -0.000910
# 2019-12-27 16:00:00 -0.001276 -0.001276 -0.009562
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
weight_all_portfolio_return = all_3_portfolio_returns.dot(weights)
# Display sample data
weight_all_portfolio_return
# Out:
# Date
# 2018-01-03 16:00:00   -0.010526
# 2018-01-04 16:00:00   -0.011027
# 2018-01-05 16:00:00    0.012116
# 2018-01-08 16:00:00    0.045662
# 2018-01-09 16:00:00   -0.004920
#                          ...
# 2019-12-20 16:00:00   -0.000865
# 2019-12-23 16:00:00    0.022012
# 2019-12-24 13:00:00    0.010724
# 2019-12-26 16:00:00    0.008633
# 2019-12-27 16:00:00   -0.004038
# Length: 500, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %% [markdown]
# # Question

# %%
# Join your returns DataFrame to the original returns DataFrame
all_combined_data = pd.concat([joined_data, all_3_portfolios], axis='columns', join='inner')
all_combined_data
# Out:
# Empty DataFrame
# Columns: [SOROS FUND MANAGEMENT LLC, PAULSON & CO.INC. , TIGER GLOBAL MANAGEMENT LLC, BERKSHIRE HATHAWAY INC, Algo 1, Algo 2, SP&60, TSLA, APPLE, BEST_BUY]
# Index: []

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

# %% [markdown]
# # Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ## Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
all_combined_data_std = all_combined.std()
all_annualized_std = all_combined_data_std * np.sqrt(252)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-86874a7821fd> in <module>
#       1 # Calculate the annualized `std`
# ----> 2 all_combined_data_std = all_combined.std()
#       3 all_annualized_std = all_combined_data_std * np.sqrt(252)
#
# NameError: name 'all_combined' is not defined

# %% [markdown]
# ## Calculate and plot rolling std with 21-day window

# %%
# Calculate rolling standard deviation
all_portfolios_21day_rolling = joined_data.rolling(window=21).std()
# Plot rolling standard deviation
all_portfolios_21day_rolling.plot(figsize=(20, 10), title='21-day')

# %% [markdown]
# ## Calculate and plot the correlation

# %%
# Calculate and plot the correlation
all_portfolios_21day_rolling.corr()

# %% [markdown]
# ## Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
all_covariance = all_combined_data["APPLE"].cov(all_combined_data["SP&60"])
# Calculate variance of S&P TSX
all_variance = all_combined_data["SP&60"].var()
# Computing beta
all_portfolio_beta = covariance / variance
# Plot beta trend
portfolio_beta

# %% [markdown]
# # Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
all_sharpe_ratios = ((all_combined_data.mean()-all_combined_data['SP&60'].mean()) * 252) / (all_combined_data.std() * np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
all_sharpe_ratios.plot(kind='bar', figsize=(20, 10), title='Sharpe Ration')

# %% [markdown]
# # How does your portfolio do?
# Write your answer here!

# %% [markdown]
# Answer:
